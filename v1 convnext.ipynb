# %%
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications.convnext import ConvNeXtBase
from tensorflow.keras.applications.convnext import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
# Out:
# 2022-07-23 16:35:57.947237: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-23 16:35:58.671194: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-07-23 16:35:58.671278: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-07-23 16:35:58.789475: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-07-23 16:36:00.299393: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-07-23 16:36:00.299543: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-07-23 16:36:00.299558: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
img_size = 128
IMAGE_SIZE = [img_size, img_size]

# %%
'''train_path="/home/nayan/Documents/Thesis/dataset/test_trn jonathanrjpereira rice-disease/train_set"
test_path="/home/nayan/Documents/Thesis/dataset/test_trn jonathanrjpereira rice-disease/test_set"
val_path="/home/nayan/Documents/Thesis/dataset/test_trn jonathanrjpereira rice-disease/test_set"'''

train_path="/home/nayan/Documents/Thesis/dataset/new clean/train"
test_path= "/home/nayan/Documents/Thesis/dataset/new clean/test"
val_path=  "/home/nayan/Documents/Thesis/dataset/new clean/test"

# %%
x_train=[]

for folder in os.listdir(train_path):
    sub_path=train_path+"/"+folder
    print(sub_path)
    for img in os.listdir(sub_path):
        image_path=sub_path+"/"+img
        img_arr=cv2.imread(image_path)
        img_arr=cv2.resize(img_arr,(img_size,img_size))
        x_train.append(img_arr)
# Out:
# /home/nayan/Documents/Thesis/dataset/new clean/train/Brown_Spot
# /home/nayan/Documents/Thesis/dataset/new clean/train/Hispa
# /home/nayan/Documents/Thesis/dataset/new clean/train/Leaf_Blast

# %%
x_test=[]

for folder in os.listdir(test_path):
    sub_path=test_path+"/"+folder
    print(sub_path)
    for img in os.listdir(sub_path):
        image_path=sub_path+"/"+img
        img_arr=cv2.imread(image_path)
        img_arr=cv2.resize(img_arr,(img_size,img_size))
        x_test.append(img_arr)
# Out:
# /home/nayan/Documents/Thesis/dataset/new clean/test/Brown_Spot
# /home/nayan/Documents/Thesis/dataset/new clean/test/Hispa
# /home/nayan/Documents/Thesis/dataset/new clean/test/Leaf_Blast

# %%
x_val=[]

for folder in os.listdir(val_path):
    sub_path=val_path+"/"+folder
    print(sub_path)
    for img in os.listdir(sub_path):
        image_path=sub_path+"/"+img
        img_arr=cv2.imread(image_path)
        img_arr=cv2.resize(img_arr,(img_size,img_size))
        x_val.append(img_arr)
# Out:
# /home/nayan/Documents/Thesis/dataset/new clean/test/Brown_Spot
# /home/nayan/Documents/Thesis/dataset/new clean/test/Hispa
# /home/nayan/Documents/Thesis/dataset/new clean/test/Leaf_Blast

# %%
train_x=np.array(x_train)
test_x=np.array(x_test)
val_x=np.array(x_val)

# %%
train_x.shape,test_x.shape,val_x.shape
# Out:
# ((441, 128, 128, 3), (76, 128, 128, 3), (76, 128, 128, 3))

# %%
train_x=train_x/255.0
test_x=test_x/255.0
val_x=val_x/255.0

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# train_datagen = ImageDataGenerator(rescale = 1./255,
#                                    shear_range = 0.2,
#                                    zoom_range = 0.2,
#                                    horizontal_flip = True)

train_datagen = ImageDataGenerator(featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    zca_epsilon=1e-06,
    rotation_range=0,
    width_shift_range=0.0,
    height_shift_range=0.0,
    brightness_range=None,
    shear_range=0.0,
    zoom_range=0.0,
    channel_shift_range=0.0,
    fill_mode="nearest",
    cval=0.0,
    horizontal_flip=False,
    vertical_flip=False,
    rescale=None,
    preprocessing_function=None,
    data_format=None,
    validation_split=0.0,
    dtype=None)
test_datagen = ImageDataGenerator(featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    zca_epsilon=1e-06,
    rotation_range=0,
    width_shift_range=0.0,
    height_shift_range=0.0,
    brightness_range=None,
    shear_range=0.0,
    zoom_range=0.0,
    channel_shift_range=0.0,
    fill_mode="nearest",
    cval=0.0,
    horizontal_flip=False,
    vertical_flip=False,
    rescale=None,
    preprocessing_function=None,
    data_format=None,
    validation_split=0.0,
    dtype=None)
val_datagen = ImageDataGenerator(featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    zca_epsilon=1e-06,
    rotation_range=0,
    width_shift_range=0.0,
    height_shift_range=0.0,
    brightness_range=None,
    shear_range=0.0,
    zoom_range=0.0,
    channel_shift_range=0.0,
    fill_mode="nearest",
    cval=0.0,
    horizontal_flip=False,
    vertical_flip=False,
    rescale=None,
    preprocessing_function=None,
    data_format=None,
    validation_split=0.0,
    dtype=None)


training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size = (img_size, img_size),
                                                 batch_size = 32,
                                                 class_mode = 'sparse')

test_set = test_datagen.flow_from_directory(test_path,
                                            target_size = (img_size, img_size),
                                            batch_size = 32,
                                            class_mode = 'sparse')

val_set = val_datagen.flow_from_directory(val_path,
                                            target_size = (img_size, img_size),
                                            batch_size = 32,
                                            class_mode = 'sparse')
# Out:
# Found 441 images belonging to 3 classes.
# Found 76 images belonging to 3 classes.
# Found 76 images belonging to 3 classes.

# %%
training_set.class_indices
# Out:
# {'Brown_Spot': 0, 'Hispa': 1, 'Leaf_Blast': 2}

# %%
train_y=training_set.classes
test_y=test_set.classes
val_y=val_set.classes
train_y.shape,test_y.shape,val_y.shape
# Out:
# ((441,), (76,), (76,))

# %%
# add preprocessing layer to the front of VGG
convnet = ConvNeXtBase(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)
# Out:
# 2022-07-23 16:37:11.137000: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 16:37:11.137719: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nayan/anaconda3/envs/nightGpu/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-07-23 16:37:11.137804: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nayan/anaconda3/envs/nightGpu/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-07-23 16:37:11.137874: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nayan/anaconda3/envs/nightGpu/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-07-23 16:37:11.137942: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nayan/anaconda3/envs/nightGpu/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-07-23 16:37:11.138007: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nayan/anaconda3/envs/nightGpu/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-07-23 16:37:11.138071: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nayan/anaconda3/envs/nightGpu/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-07-23 16:37:11.138135: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nayan/anaconda3/envs/nightGpu/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-07-23 16:37:11.138201: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nayan/anaconda3/envs/nightGpu/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-07-23 16:37:11.138211: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-07-23 16:37:11.139237: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
for layer in resnet.layers:
    layer.trainable = False

# %%
x = Flatten()(resnet.output)

prediction = Dense(3, activation='softmax')(x)

# %%
# create a model object
model = Model(inputs=resnet.input, outputs=prediction)

# view the structure of the model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  convnext_base_prestem_normaliz  (None, 128, 128, 3)  0          ['input_1[0][0]']
#  ation (Normalization)
#
#  convnext_base_stem (Sequential  (None, 32, 32, 128)  6528       ['convnext_base_prestem_normaliza
#  )                                                               tion[0][0]']
#
#  convnext_base_stage_0_block_0_  (None, 32, 32, 128)  6400       ['convnext_base_stem[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_base_stage_0_block_0_  (None, 32, 32, 128)  256        ['convnext_base_stage_0_block_0_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_base_stage_0_block_0_  (None, 32, 32, 512)  66048      ['convnext_base_stage_0_block_0_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_base_stage_0_block_0_  (None, 32, 32, 512)  0          ['convnext_base_stage_0_block_0_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_base_stage_0_block_0_  (None, 32, 32, 128)  65664      ['convnext_base_stage_0_block_0_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_base_stage_0_block_0_  (None, 32, 32, 128)  128        ['convnext_base_stage_0_block_0_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_base_stage_0_block_0_  (None, 32, 32, 128)  0          ['convnext_base_stage_0_block_0_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 32, 32, 128)  0          ['convnext_base_stem[0][0]',
#  da)                                                              'convnext_base_stage_0_block_0_i
#                                                                  dentity[0][0]']
#
#  convnext_base_stage_0_block_1_  (None, 32, 32, 128)  6400       ['tf.__operators__.add[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_base_stage_0_block_1_  (None, 32, 32, 128)  256        ['convnext_base_stage_0_block_1_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_base_stage_0_block_1_  (None, 32, 32, 512)  66048      ['convnext_base_stage_0_block_1_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_base_stage_0_block_1_  (None, 32, 32, 512)  0          ['convnext_base_stage_0_block_1_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_base_stage_0_block_1_  (None, 32, 32, 128)  65664      ['convnext_base_stage_0_block_1_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_base_stage_0_block_1_  (None, 32, 32, 128)  128        ['convnext_base_stage_0_block_1_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_base_stage_0_block_1_  (None, 32, 32, 128)  0          ['convnext_base_stage_0_block_1_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 32, 32, 128)  0          ['tf.__operators__.add[0][0]',
#  mbda)                                                            'convnext_base_stage_0_block_1_i
#                                                                  dentity[0][0]']
#
#  convnext_base_stage_0_block_2_  (None, 32, 32, 128)  6400       ['tf.__operators__.add_1[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_base_stage_0_block_2_  (None, 32, 32, 128)  256        ['convnext_base_stage_0_block_2_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_base_stage_0_block_2_  (None, 32, 32, 512)  66048      ['convnext_base_stage_0_block_2_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_base_stage_0_block_2_  (None, 32, 32, 512)  0          ['convnext_base_stage_0_block_2_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_base_stage_0_block_2_  (None, 32, 32, 128)  65664      ['convnext_base_stage_0_block_2_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_base_stage_0_block_2_  (None, 32, 32, 128)  128        ['convnext_base_stage_0_block_2_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_base_stage_0_block_2_  (None, 32, 32, 128)  0          ['convnext_base_stage_0_block_2_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 32, 32, 128)  0          ['tf.__operators__.add_1[0][0]',
#  mbda)                                                            'convnext_base_stage_0_block_2_i
#                                                                  dentity[0][0]']
#
#  convnext_base_downsampling_blo  (None, 16, 16, 256)  131584     ['tf.__operators__.add_2[0][0]']
#  ck_0 (Sequential)
#
#  convnext_base_stage_1_block_0_  (None, 16, 16, 256)  12800      ['convnext_base_downsampling_bloc
#  depthwise_conv (Conv2D)                                         k_0[0][0]']
#
#  convnext_base_stage_1_block_0_  (None, 16, 16, 256)  512        ['convnext_base_stage_1_block_0_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_base_stage_1_block_0_  (None, 16, 16, 1024  263168     ['convnext_base_stage_1_block_0_l
#  pointwise_conv_1 (Dense)       )                                ayernorm[0][0]']
#
#  convnext_base_stage_1_block_0_  (None, 16, 16, 1024  0          ['convnext_base_stage_1_block_0_p
#  gelu (Activation)              )                                ointwise_conv_1[0][0]']
#
#  convnext_base_stage_1_block_0_  (None, 16, 16, 256)  262400     ['convnext_base_stage_1_block_0_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_base_stage_1_block_0_  (None, 16, 16, 256)  256        ['convnext_base_stage_1_block_0_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_base_stage_1_block_0_  (None, 16, 16, 256)  0          ['convnext_base_stage_1_block_0_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 16, 16, 256)  0          ['convnext_base_downsampling_bloc
#  mbda)                                                           k_0[0][0]',
#                                                                   'convnext_base_stage_1_block_0_i
#                                                                  dentity[0][0]']
#
#  convnext_base_stage_1_block_1_  (None, 16, 16, 256)  12800      ['tf.__operators__.add_3[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_base_stage_1_block_1_  (None, 16, 16, 256)  512        ['convnext_base_stage_1_block_1_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_base_stage_1_block_1_  (None, 16, 16, 1024  263168     ['convnext_base_stage_1_block_1_l
#  pointwise_conv_1 (Dense)       )                                ayernorm[0][0]']
#
#  convnext_base_stage_1_block_1_  (None, 16, 16, 1024  0          ['convnext_base_stage_1_block_1_p
#  gelu (Activation)              )                                ointwise_conv_1[0][0]']
#
#  convnext_base_stage_1_block_1_  (None, 16, 16, 256)  262400     ['convnext_base_stage_1_block_1_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_base_stage_1_block_1_  (None, 16, 16, 256)  256        ['convnext_base_stage_1_block_1_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_base_stage_1_block_1_  (None, 16, 16, 256)  0          ['convnext_base_stage_1_block_1_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 16, 16, 256)  0          ['tf.__operators__.add_3[0][0]',
#  mbda)                                                            'convnext_base_stage_1_block_1_i
#                                                                  dentity[0][0]']
#
#  convnext_base_stage_1_block_2_  (None, 16, 16, 256)  12800      ['tf.__operators__.add_4[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_base_stage_1_block_2_  (None, 16, 16, 256)  512        ['convnext_base_stage_1_block_2_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_base_stage_1_block_2_  (None, 16, 16, 1024  263168     ['convnext_base_stage_1_block_2_l
#  pointwise_conv_1 (Dense)       )                                ayernorm[0][0]']
#
#  convnext_base_stage_1_block_2_  (None, 16, 16, 1024  0          ['convnext_base_stage_1_block_2_p
#  gelu (Activation)              )                                ointwise_conv_1[0][0]']
#
#  convnext_base_stage_1_block_2_  (None, 16, 16, 256)  262400     ['convnext_base_stage_1_block_2_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_base_stage_1_block_2_  (None, 16, 16, 256)  256        ['convnext_base_stage_1_block_2_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_base_stage_1_block_2_  (None, 16, 16, 256)  0          ['convnext_base_stage_1_block_2_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 16, 16, 256)  0          ['tf.__operators__.add_4[0][0]',
#  mbda)                                                            'convnext_base_stage_1_block_2_i
#                                                                  dentity[0][0]']
#
#  convnext_base_downsampling_blo  (None, 8, 8, 512)   525312      ['tf.__operators__.add_5[0][0]']
#  ck_1 (Sequential)
#
#  convnext_base_stage_2_block_0_  (None, 8, 8, 512)   25600       ['convnext_base_downsampling_bloc
#  depthwise_conv (Conv2D)                                         k_1[0][0]']
#
#  convnext_base_stage_2_block_0_  (None, 8, 8, 512)   1024        ['convnext_base_stage_2_block_0_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_base_stage_2_block_0_  (None, 8, 8, 2048)  1050624     ['convnext_base_stage_2_block_0_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_base_stage_2_block_0_  (None, 8, 8, 2048)  0           ['convnext_base_stage_2_block_0_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_block_0_  (None, 8, 8, 512)   1049088     ['convnext_base_stage_2_block_0_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_base_stage_2_block_0_  (None, 8, 8, 512)   512         ['convnext_base_stage_2_block_0_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_base_stage_2_block_0_  (None, 8, 8, 512)   0           ['convnext_base_stage_2_block_0_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 8, 8, 512)   0           ['convnext_base_downsampling_bloc
#  mbda)                                                           k_1[0][0]',
#                                                                   'convnext_base_stage_2_block_0_i
#                                                                  dentity[0][0]']
#
#  convnext_base_stage_2_block_1_  (None, 8, 8, 512)   25600       ['tf.__operators__.add_6[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_base_stage_2_block_1_  (None, 8, 8, 512)   1024        ['convnext_base_stage_2_block_1_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_base_stage_2_block_1_  (None, 8, 8, 2048)  1050624     ['convnext_base_stage_2_block_1_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_base_stage_2_block_1_  (None, 8, 8, 2048)  0           ['convnext_base_stage_2_block_1_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_block_1_  (None, 8, 8, 512)   1049088     ['convnext_base_stage_2_block_1_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_base_stage_2_block_1_  (None, 8, 8, 512)   512         ['convnext_base_stage_2_block_1_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_base_stage_2_block_1_  (None, 8, 8, 512)   0           ['convnext_base_stage_2_block_1_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 8, 8, 512)   0           ['tf.__operators__.add_6[0][0]',
#  mbda)                                                            'convnext_base_stage_2_block_1_i
#                                                                  dentity[0][0]']
#
#  convnext_base_stage_2_block_2_  (None, 8, 8, 512)   25600       ['tf.__operators__.add_7[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_base_stage_2_block_2_  (None, 8, 8, 512)   1024        ['convnext_base_stage_2_block_2_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_base_stage_2_block_2_  (None, 8, 8, 2048)  1050624     ['convnext_base_stage_2_block_2_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_base_stage_2_block_2_  (None, 8, 8, 2048)  0           ['convnext_base_stage_2_block_2_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_block_2_  (None, 8, 8, 512)   1049088     ['convnext_base_stage_2_block_2_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_base_stage_2_block_2_  (None, 8, 8, 512)   512         ['convnext_base_stage_2_block_2_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_base_stage_2_block_2_  (None, 8, 8, 512)   0           ['convnext_base_stage_2_block_2_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_8 (TFOpLa  (None, 8, 8, 512)   0           ['tf.__operators__.add_7[0][0]',
#  mbda)                                                            'convnext_base_stage_2_block_2_i
#                                                                  dentity[0][0]']
#
#  convnext_base_stage_2_block_3_  (None, 8, 8, 512)   25600       ['tf.__operators__.add_8[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_base_stage_2_block_3_  (None, 8, 8, 512)   1024        ['convnext_base_stage_2_block_3_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_base_stage_2_block_3_  (None, 8, 8, 2048)  1050624     ['convnext_base_stage_2_block_3_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_base_stage_2_block_3_  (None, 8, 8, 2048)  0           ['convnext_base_stage_2_block_3_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_block_3_  (None, 8, 8, 512)   1049088     ['convnext_base_stage_2_block_3_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_base_stage_2_block_3_  (None, 8, 8, 512)   512         ['convnext_base_stage_2_block_3_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_base_stage_2_block_3_  (None, 8, 8, 512)   0           ['convnext_base_stage_2_block_3_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 8, 8, 512)   0           ['tf.__operators__.add_8[0][0]',
#  mbda)                                                            'convnext_base_stage_2_block_3_i
#                                                                  dentity[0][0]']
#
#  convnext_base_stage_2_block_4_  (None, 8, 8, 512)   25600       ['tf.__operators__.add_9[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_base_stage_2_block_4_  (None, 8, 8, 512)   1024        ['convnext_base_stage_2_block_4_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_base_stage_2_block_4_  (None, 8, 8, 2048)  1050624     ['convnext_base_stage_2_block_4_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_base_stage_2_block_4_  (None, 8, 8, 2048)  0           ['convnext_base_stage_2_block_4_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_block_4_  (None, 8, 8, 512)   1049088     ['convnext_base_stage_2_block_4_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_base_stage_2_block_4_  (None, 8, 8, 512)   512         ['convnext_base_stage_2_block_4_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_base_stage_2_block_4_  (None, 8, 8, 512)   0           ['convnext_base_stage_2_block_4_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_10 (TFOpL  (None, 8, 8, 512)   0           ['tf.__operators__.add_9[0][0]',
#  ambda)                                                           'convnext_base_stage_2_block_4_i
#                                                                  dentity[0][0]']
#
#  convnext_base_stage_2_block_5_  (None, 8, 8, 512)   25600       ['tf.__operators__.add_10[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_base_stage_2_block_5_  (None, 8, 8, 512)   1024        ['convnext_base_stage_2_block_5_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_base_stage_2_block_5_  (None, 8, 8, 2048)  1050624     ['convnext_base_stage_2_block_5_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_base_stage_2_block_5_  (None, 8, 8, 2048)  0           ['convnext_base_stage_2_block_5_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_block_5_  (None, 8, 8, 512)   1049088     ['convnext_base_stage_2_block_5_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_base_stage_2_block_5_  (None, 8, 8, 512)   512         ['convnext_base_stage_2_block_5_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_base_stage_2_block_5_  (None, 8, 8, 512)   0           ['convnext_base_stage_2_block_5_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_11 (TFOpL  (None, 8, 8, 512)   0           ['tf.__operators__.add_10[0][0]',
#  ambda)                                                           'convnext_base_stage_2_block_5_i
#                                                                  dentity[0][0]']
#
#  convnext_base_stage_2_block_6_  (None, 8, 8, 512)   25600       ['tf.__operators__.add_11[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_base_stage_2_block_6_  (None, 8, 8, 512)   1024        ['convnext_base_stage_2_block_6_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_base_stage_2_block_6_  (None, 8, 8, 2048)  1050624     ['convnext_base_stage_2_block_6_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_base_stage_2_block_6_  (None, 8, 8, 2048)  0           ['convnext_base_stage_2_block_6_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_block_6_  (None, 8, 8, 512)   1049088     ['convnext_base_stage_2_block_6_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_base_stage_2_block_6_  (None, 8, 8, 512)   512         ['convnext_base_stage_2_block_6_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_base_stage_2_block_6_  (None, 8, 8, 512)   0           ['convnext_base_stage_2_block_6_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_12 (TFOpL  (None, 8, 8, 512)   0           ['tf.__operators__.add_11[0][0]',
#  ambda)                                                           'convnext_base_stage_2_block_6_i
#                                                                  dentity[0][0]']
#
#  convnext_base_stage_2_block_7_  (None, 8, 8, 512)   25600       ['tf.__operators__.add_12[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_base_stage_2_block_7_  (None, 8, 8, 512)   1024        ['convnext_base_stage_2_block_7_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_base_stage_2_block_7_  (None, 8, 8, 2048)  1050624     ['convnext_base_stage_2_block_7_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_base_stage_2_block_7_  (None, 8, 8, 2048)  0           ['convnext_base_stage_2_block_7_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_block_7_  (None, 8, 8, 512)   1049088     ['convnext_base_stage_2_block_7_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_base_stage_2_block_7_  (None, 8, 8, 512)   512         ['convnext_base_stage_2_block_7_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_base_stage_2_block_7_  (None, 8, 8, 512)   0           ['convnext_base_stage_2_block_7_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_13 (TFOpL  (None, 8, 8, 512)   0           ['tf.__operators__.add_12[0][0]',
#  ambda)                                                           'convnext_base_stage_2_block_7_i
#                                                                  dentity[0][0]']
#
#  convnext_base_stage_2_block_8_  (None, 8, 8, 512)   25600       ['tf.__operators__.add_13[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_base_stage_2_block_8_  (None, 8, 8, 512)   1024        ['convnext_base_stage_2_block_8_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_base_stage_2_block_8_  (None, 8, 8, 2048)  1050624     ['convnext_base_stage_2_block_8_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_base_stage_2_block_8_  (None, 8, 8, 2048)  0           ['convnext_base_stage_2_block_8_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_block_8_  (None, 8, 8, 512)   1049088     ['convnext_base_stage_2_block_8_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_base_stage_2_block_8_  (None, 8, 8, 512)   512         ['convnext_base_stage_2_block_8_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_base_stage_2_block_8_  (None, 8, 8, 512)   0           ['convnext_base_stage_2_block_8_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_14 (TFOpL  (None, 8, 8, 512)   0           ['tf.__operators__.add_13[0][0]',
#  ambda)                                                           'convnext_base_stage_2_block_8_i
#                                                                  dentity[0][0]']
#
#  convnext_base_stage_2_block_9_  (None, 8, 8, 512)   25600       ['tf.__operators__.add_14[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_base_stage_2_block_9_  (None, 8, 8, 512)   1024        ['convnext_base_stage_2_block_9_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_base_stage_2_block_9_  (None, 8, 8, 2048)  1050624     ['convnext_base_stage_2_block_9_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_base_stage_2_block_9_  (None, 8, 8, 2048)  0           ['convnext_base_stage_2_block_9_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_block_9_  (None, 8, 8, 512)   1049088     ['convnext_base_stage_2_block_9_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_base_stage_2_block_9_  (None, 8, 8, 512)   512         ['convnext_base_stage_2_block_9_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_base_stage_2_block_9_  (None, 8, 8, 512)   0           ['convnext_base_stage_2_block_9_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_15 (TFOpL  (None, 8, 8, 512)   0           ['tf.__operators__.add_14[0][0]',
#  ambda)                                                           'convnext_base_stage_2_block_9_i
#                                                                  dentity[0][0]']
#
#  convnext_base_stage_2_block_10  (None, 8, 8, 512)   25600       ['tf.__operators__.add_15[0][0]']
#  _depthwise_conv (Conv2D)
#
#  convnext_base_stage_2_block_10  (None, 8, 8, 512)   1024        ['convnext_base_stage_2_block_10_
#  _layernorm (LayerNormalization                                  depthwise_conv[0][0]']
#  )
#
#  convnext_base_stage_2_block_10  (None, 8, 8, 2048)  1050624     ['convnext_base_stage_2_block_10_
#  _pointwise_conv_1 (Dense)                                       layernorm[0][0]']
#
#  convnext_base_stage_2_block_10  (None, 8, 8, 2048)  0           ['convnext_base_stage_2_block_10_
#  _gelu (Activation)                                              pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_block_10  (None, 8, 8, 512)   1049088     ['convnext_base_stage_2_block_10_
#  _pointwise_conv_2 (Dense)                                       gelu[0][0]']
#
#  convnext_base_stage_2_block_10  (None, 8, 8, 512)   512         ['convnext_base_stage_2_block_10_
#  _layer_scale (LayerScale)                                       pointwise_conv_2[0][0]']
#
#  convnext_base_stage_2_block_10  (None, 8, 8, 512)   0           ['convnext_base_stage_2_block_10_
#  _identity (Activation)                                          layer_scale[0][0]']
#
#  tf.__operators__.add_16 (TFOpL  (None, 8, 8, 512)   0           ['tf.__operators__.add_15[0][0]',
#  ambda)                                                           'convnext_base_stage_2_block_10_
#                                                                  identity[0][0]']
#
#  convnext_base_stage_2_block_11  (None, 8, 8, 512)   25600       ['tf.__operators__.add_16[0][0]']
#  _depthwise_conv (Conv2D)
#
#  convnext_base_stage_2_block_11  (None, 8, 8, 512)   1024        ['convnext_base_stage_2_block_11_
#  _layernorm (LayerNormalization                                  depthwise_conv[0][0]']
#  )
#
#  convnext_base_stage_2_block_11  (None, 8, 8, 2048)  1050624     ['convnext_base_stage_2_block_11_
#  _pointwise_conv_1 (Dense)                                       layernorm[0][0]']
#
#  convnext_base_stage_2_block_11  (None, 8, 8, 2048)  0           ['convnext_base_stage_2_block_11_
#  _gelu (Activation)                                              pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_block_11  (None, 8, 8, 512)   1049088     ['convnext_base_stage_2_block_11_
#  _pointwise_conv_2 (Dense)                                       gelu[0][0]']
#
#  convnext_base_stage_2_block_11  (None, 8, 8, 512)   512         ['convnext_base_stage_2_block_11_
#  _layer_scale (LayerScale)                                       pointwise_conv_2[0][0]']
#
#  convnext_base_stage_2_block_11  (None, 8, 8, 512)   0           ['convnext_base_stage_2_block_11_
#  _identity (Activation)                                          layer_scale[0][0]']
#
#  tf.__operators__.add_17 (TFOpL  (None, 8, 8, 512)   0           ['tf.__operators__.add_16[0][0]',
#  ambda)                                                           'convnext_base_stage_2_block_11_
#                                                                  identity[0][0]']
#
#  convnext_base_stage_2_block_12  (None, 8, 8, 512)   25600       ['tf.__operators__.add_17[0][0]']
#  _depthwise_conv (Conv2D)
#
#  convnext_base_stage_2_block_12  (None, 8, 8, 512)   1024        ['convnext_base_stage_2_block_12_
#  _layernorm (LayerNormalization                                  depthwise_conv[0][0]']
#  )
#
#  convnext_base_stage_2_block_12  (None, 8, 8, 2048)  1050624     ['convnext_base_stage_2_block_12_
#  _pointwise_conv_1 (Dense)                                       layernorm[0][0]']
#
#  convnext_base_stage_2_block_12  (None, 8, 8, 2048)  0           ['convnext_base_stage_2_block_12_
#  _gelu (Activation)                                              pointwise_conv_1[0][0]']
# ...
#
#  convnext_base_stage_2_block_24  (None, 8, 8, 2048)  1050624     ['convnext_base_stage_2_block_24_
#  _pointwise_conv_1 (Dense)                                       layernorm[0][0]']
#
#  convnext_base_stage_2_block_24  (None, 8, 8, 2048)  0           ['convnext_base_stage_2_block_24_
#  _gelu (Activation)                                              pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_block_24  (None, 8, 8, 512)   1049088     ['convnext_base_stage_2_block_24_
#  _pointwise_conv_2 (Dense)                                       gelu[0][0]']
#
#  convnext_base_stage_2_block_24  (None, 8, 8, 512)   512         ['convnext_base_stage_2_block_24_
#  _layer_scale (LayerScale)                                       pointwise_conv_2[0][0]']
#
#  convnext_base_stage_2_block_24  (None, 8, 8, 512)   0           ['convnext_base_stage_2_block_24_
#  _identity (Activation)                                          layer_scale[0][0]']
#
#  tf.__operators__.add_30 (TFOpL  (None, 8, 8, 512)   0           ['tf.__operators__.add_29[0][0]',
#  ambda)                                                           'convnext_base_stage_2_block_24_
#                                                                  identity[0][0]']
#
#  convnext_base_stage_2_block_25  (None, 8, 8, 512)   25600       ['tf.__operators__.add_30[0][0]']
#  _depthwise_conv (Conv2D)
#
#  convnext_base_stage_2_block_25  (None, 8, 8, 512)   1024        ['convnext_base_stage_2_block_25_
#  _layernorm (LayerNormalization                                  depthwise_conv[0][0]']
#  )
#
#  convnext_base_stage_2_block_25  (None, 8, 8, 2048)  1050624     ['convnext_base_stage_2_block_25_
#  _pointwise_conv_1 (Dense)                                       layernorm[0][0]']
#
#  convnext_base_stage_2_block_25  (None, 8, 8, 2048)  0           ['convnext_base_stage_2_block_25_
#  _gelu (Activation)                                              pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_block_25  (None, 8, 8, 512)   1049088     ['convnext_base_stage_2_block_25_
#  _pointwise_conv_2 (Dense)                                       gelu[0][0]']
#
#  convnext_base_stage_2_block_25  (None, 8, 8, 512)   512         ['convnext_base_stage_2_block_25_
#  _layer_scale (LayerScale)                                       pointwise_conv_2[0][0]']
#
#  convnext_base_stage_2_block_25  (None, 8, 8, 512)   0           ['convnext_base_stage_2_block_25_
#  _identity (Activation)                                          layer_scale[0][0]']
#
#  tf.__operators__.add_31 (TFOpL  (None, 8, 8, 512)   0           ['tf.__operators__.add_30[0][0]',
#  ambda)                                                           'convnext_base_stage_2_block_25_
#                                                                  identity[0][0]']
#
#  convnext_base_stage_2_block_26  (None, 8, 8, 512)   25600       ['tf.__operators__.add_31[0][0]']
#  _depthwise_conv (Conv2D)
#
#  convnext_base_stage_2_block_26  (None, 8, 8, 512)   1024        ['convnext_base_stage_2_block_26_
#  _layernorm (LayerNormalization                                  depthwise_conv[0][0]']
#  )
#
#  convnext_base_stage_2_block_26  (None, 8, 8, 2048)  1050624     ['convnext_base_stage_2_block_26_
#  _pointwise_conv_1 (Dense)                                       layernorm[0][0]']
#
#  convnext_base_stage_2_block_26  (None, 8, 8, 2048)  0           ['convnext_base_stage_2_block_26_
#  _gelu (Activation)                                              pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_block_26  (None, 8, 8, 512)   1049088     ['convnext_base_stage_2_block_26_
#  _pointwise_conv_2 (Dense)                                       gelu[0][0]']
#
#  convnext_base_stage_2_block_26  (None, 8, 8, 512)   512         ['convnext_base_stage_2_block_26_
#  _layer_scale (LayerScale)                                       pointwise_conv_2[0][0]']
#
#  convnext_base_stage_2_block_26  (None, 8, 8, 512)   0           ['convnext_base_stage_2_block_26_
#  _identity (Activation)                                          layer_scale[0][0]']
#
#  tf.__operators__.add_32 (TFOpL  (None, 8, 8, 512)   0           ['tf.__operators__.add_31[0][0]',
#  ambda)                                                           'convnext_base_stage_2_block_26_
#                                                                  identity[0][0]']
#
#  convnext_base_downsampling_blo  (None, 4, 4, 1024)  2099200     ['tf.__operators__.add_32[0][0]']
#  ck_2 (Sequential)
#
#  convnext_base_stage_3_block_0_  (None, 4, 4, 1024)  51200       ['convnext_base_downsampling_bloc
#  depthwise_conv (Conv2D)                                         k_2[0][0]']
#
#  convnext_base_stage_3_block_0_  (None, 4, 4, 1024)  2048        ['convnext_base_stage_3_block_0_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_base_stage_3_block_0_  (None, 4, 4, 4096)  4198400     ['convnext_base_stage_3_block_0_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_base_stage_3_block_0_  (None, 4, 4, 4096)  0           ['convnext_base_stage_3_block_0_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_base_stage_3_block_0_  (None, 4, 4, 1024)  4195328     ['convnext_base_stage_3_block_0_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_base_stage_3_block_0_  (None, 4, 4, 1024)  1024        ['convnext_base_stage_3_block_0_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_base_stage_3_block_0_  (None, 4, 4, 1024)  0           ['convnext_base_stage_3_block_0_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_33 (TFOpL  (None, 4, 4, 1024)  0           ['convnext_base_downsampling_bloc
#  ambda)                                                          k_2[0][0]',
#                                                                   'convnext_base_stage_3_block_0_i
#                                                                  dentity[0][0]']
#
#  convnext_base_stage_3_block_1_  (None, 4, 4, 1024)  51200       ['tf.__operators__.add_33[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_base_stage_3_block_1_  (None, 4, 4, 1024)  2048        ['convnext_base_stage_3_block_1_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_base_stage_3_block_1_  (None, 4, 4, 4096)  4198400     ['convnext_base_stage_3_block_1_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_base_stage_3_block_1_  (None, 4, 4, 4096)  0           ['convnext_base_stage_3_block_1_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_base_stage_3_block_1_  (None, 4, 4, 1024)  4195328     ['convnext_base_stage_3_block_1_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_base_stage_3_block_1_  (None, 4, 4, 1024)  1024        ['convnext_base_stage_3_block_1_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_base_stage_3_block_1_  (None, 4, 4, 1024)  0           ['convnext_base_stage_3_block_1_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_34 (TFOpL  (None, 4, 4, 1024)  0           ['tf.__operators__.add_33[0][0]',
#  ambda)                                                           'convnext_base_stage_3_block_1_i
#                                                                  dentity[0][0]']
#
#  convnext_base_stage_3_block_2_  (None, 4, 4, 1024)  51200       ['tf.__operators__.add_34[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_base_stage_3_block_2_  (None, 4, 4, 1024)  2048        ['convnext_base_stage_3_block_2_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_base_stage_3_block_2_  (None, 4, 4, 4096)  4198400     ['convnext_base_stage_3_block_2_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_base_stage_3_block_2_  (None, 4, 4, 4096)  0           ['convnext_base_stage_3_block_2_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_base_stage_3_block_2_  (None, 4, 4, 1024)  4195328     ['convnext_base_stage_3_block_2_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_base_stage_3_block_2_  (None, 4, 4, 1024)  1024        ['convnext_base_stage_3_block_2_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_base_stage_3_block_2_  (None, 4, 4, 1024)  0           ['convnext_base_stage_3_block_2_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_35 (TFOpL  (None, 4, 4, 1024)  0           ['tf.__operators__.add_34[0][0]',
#  ambda)                                                           'convnext_base_stage_3_block_2_i
#                                                                  dentity[0][0]']
#
#  layer_normalization (LayerNorm  (None, 4, 4, 1024)  2048        ['tf.__operators__.add_35[0][0]']
#  alization)
#
#  flatten (Flatten)              (None, 16384)        0           ['layer_normalization[0][0]']
#
#  dense (Dense)                  (None, 3)            49155       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 87,615,619
# Trainable params: 49,155
# Non-trainable params: 87,566,464
# __________________________________________________________________________________________________

# %%
# tell the model what cost and optimization method to use
model.compile(
  loss='sparse_categorical_crossentropy',
  optimizer="adam",
  metrics=['accuracy']
)

# %%
# fit the model
history = model.fit(
  train_x,
  train_y,
  validation_data=(val_x,val_y),
  epochs=15,  
  batch_size=32,shuffle=True)
# Out:
# Epoch 1/15
# 2022-07-23 16:38:29.830506: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7efecd6237f0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-07-23 16:38:29.830539: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): Host, Default Version
# 2022-07-23 16:38:30.019395: I tensorflow/compiler/jit/xla_compilation_cache.cc:476] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 14/14 [==============================] - 484s 34s/step - loss: 1.4092 - accuracy: 0.5964 - val_loss: 1.0187 - val_accuracy: 0.6447
# Epoch 2/15
# 14/14 [==============================] - 518s 38s/step - loss: 0.5502 - accuracy: 0.7982 - val_loss: 1.0207 - val_accuracy: 0.6974
# Epoch 3/15
# 14/14 [==============================] - 490s 35s/step - loss: 0.3988 - accuracy: 0.8435 - val_loss: 1.2686 - val_accuracy: 0.6053
# Epoch 4/15
# 14/14 [==============================] - 484s 35s/step - loss: 0.2915 - accuracy: 0.9070 - val_loss: 0.7481 - val_accuracy: 0.7368
# Epoch 5/15
# 14/14 [==============================] - 461s 33s/step - loss: 0.2182 - accuracy: 0.9206 - val_loss: 0.9789 - val_accuracy: 0.6711
# Epoch 6/15
# 14/14 [==============================] - 460s 33s/step - loss: 0.2008 - accuracy: 0.9320 - val_loss: 1.0356 - val_accuracy: 0.6711
# Epoch 7/15
# 14/14 [==============================] - 464s 34s/step - loss: 0.1698 - accuracy: 0.9320 - val_loss: 1.1672 - val_accuracy: 0.6316
# Epoch 8/15
# 14/14 [==============================] - 464s 33s/step - loss: 0.1448 - accuracy: 0.9524 - val_loss: 0.8465 - val_accuracy: 0.7500
# Epoch 9/15
# 14/14 [==============================] - 450s 32s/step - loss: 0.0989 - accuracy: 0.9819 - val_loss: 0.7651 - val_accuracy: 0.7500
# Epoch 10/15
# 14/14 [==============================] - 450s 32s/step - loss: 0.1039 - accuracy: 0.9751 - val_loss: 0.8937 - val_accuracy: 0.7368
# Epoch 11/15
# 14/14 [==============================] - 458s 33s/step - loss: 0.0773 - accuracy: 0.9819 - val_loss: 0.9149 - val_accuracy: 0.7237
# Epoch 12/15
# 14/14 [==============================] - 462s 33s/step - loss: 0.0711 - accuracy: 0.9864 - val_loss: 0.8702 - val_accuracy: 0.7368
# Epoch 13/15
# 14/14 [==============================] - 463s 33s/step - loss: 0.0566 - accuracy: 0.9955 - val_loss: 0.8757 - val_accuracy: 0.7237
# Epoch 14/15
# 14/14 [==============================] - 464s 33s/step - loss: 0.0542 - accuracy: 0.9955 - val_loss: 0.9392 - val_accuracy: 0.7368
# Epoch 15/15
# 14/14 [==============================] - 522s 38s/step - loss: 0.0548 - accuracy: 0.9932 - val_loss: 0.9590 - val_accuracy: 0.7237
